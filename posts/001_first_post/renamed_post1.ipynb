# %% [raw]
# ---
# title: "Testing, 123"
# description: "Clever subtitle here"
# author: "Glynn Boltman"
# date: "1/23/2026"
# categories:
#   - visualization
#   - data stories
#   - comms
# ---

# %%
# ^ this is what you have to put at the beginning of every post

# %% [markdown]
# ## This is what I'm writing for content.
