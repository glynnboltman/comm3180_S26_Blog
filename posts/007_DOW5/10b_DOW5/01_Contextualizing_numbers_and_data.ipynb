# %% [markdown]
# # Contextualizing numbers and data
#
#
# ### Shooting....
#
# * _I just got shot..._
#
# ![](img/chatgpt_just_got_shot.png)

# %% [markdown]
# ## US Covid-19 Deaths
#
# ![](img/covid_deaths.png)

# %% [markdown]
# * What proportation of population is that?

# %%
round((1144539/342620143)*100, 3)
# Out:
# 0.334

# %% [markdown]
# * Find a state that has the closest population to this number

# %%
"Montana"
# Out:
# 'New Jersey'

# %% [markdown]
# ## Sexual violence in college
#
# * 1 in 4 females will experience sexual violence during their college career
#
# * How many females enrolled in college in 2021?
#   >  In fall 2021, female students made up 58 percent of total undergraduate enrollment (8.9 million students), and male students made up 42 percent (6.5 million students).
#
# * https://educationdata.org/college-enrollment-statistics
#
#
# * What number of females are likely to experience sexual violence?

# %%
0.25*8.9
# Out:
# 2.225
