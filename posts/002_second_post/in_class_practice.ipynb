# %% [raw]
# ---
# title: "Dataset of the Week (DOG)"
# description: "Assignment 2 for GitHub"
# author: "Glynn Boltman"
# date: "1/28/2026"
# categories:
#   - coursework
# ---

# %% [markdown]
# # Important information:
# ![](gym_dog.jpeg){width=400}
